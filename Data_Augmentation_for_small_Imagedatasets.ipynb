# %% [markdown]
# <a href="https://colab.research.google.com/github/pramod-mamidi/sample/blob/master/Data_Augmentation_for_small_Imagedatasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing.image import ImageDataGenerator,array_to_img
# Out:
# Using TensorFlow backend.

# %%
data = ImageDataGenerator(
    rotation_range=35,
    width_shift_range=0.3,
    height_shift_range=0.3,
    brightness_range=None,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest',
)

# %%
from google.colab import files
upl = files.upload()
# Out:
#      <input type="file" id="files-8464ef7d-9a24-40d7-908d-f1a5e2780c3c" name="files[]" multiple disabled />
#      <output id="result-8464ef7d-9a24-40d7-908d-f1a5e2780c3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving jp.png to jp (2).png

# %%
for key in upl:
  u=plt.imread(key)
u1=u.shape

# %%
plt.imshow(u)
u=u.reshape((1,)+u.shape)

# %%
i = 0
for batch in data.flow(u, batch_size=1):
  plt.figure(i)
  imgplot = plt.imshow(array_to_img(batch[0]))
  i += 1
  if i==10:
    break
